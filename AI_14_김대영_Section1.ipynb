# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import preprocessing
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import *

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df = pd.read_csv('/content/drive/My Drive/vgames.csv',sep=",",encoding="ISO-8859-1",header=0)

#research



#df = research['Year'].value_counts()
#df1 = research['Genre'].value_counts()


#print(df)
#print(df1)

#research

#research.info

#df.isnull().sum() //결측치 간단히 출력


#research.dropna(axis=1, how='all')
#research.isnull().sum()

#fillter = research.dropna(axis=1, how='all')
#fillter = research.dropna(axis=0, how='all')
#fillter.info

#df.describe()

group = df.groupby(['Genre'],as_index=False)['JP_Sales']

#group.plot(kind='bar');

# %%
matplotlib.font_manager._rebuild()

# %%
group.mean()
# Out:
#            Genre  JP_Sales
# 0         Action  0.065726
# 1      Adventure  0.045632
# 2       Fighting  0.121408
# 3           Misc  0.080157
# 4       Platform  0.194490
# 5         Puzzle  0.100782
# 6         Racing  0.070182
# 7   Role-Playing  0.245510
# 8        Shooter  0.035618
# 9     Simulation  0.083843
# 10        Sports  0.082800
# 11      Strategy  0.080068

# %%
group2 = df.groupby(['Genre'],as_index=False)['EU_Sales']
group2.mean()
# Out:
#            Genre  EU_Sales
# 0         Action  0.118490
# 1      Adventure  0.043860
# 2       Fighting  0.112406
# 3           Misc  0.119970
# 4       Platform  0.247415
# 5         Puzzle  0.090521
# 6         Racing  0.208418
# 7   Role-Playing  0.111069
# 8        Shooter  0.186426
# 9     Simulation  0.220923
# 10        Sports  0.146006
# 11      Strategy  0.064007

# %%
group3 = df.groupby(['Genre'],as_index=False)['NA_Sales']
group3.mean()
# Out:
#            Genre  NA_Sales
# 0         Action  0.224815
# 1      Adventure  0.077711
# 2       Fighting  0.236547
# 3           Misc  0.211177
# 4       Platform  0.576582
# 5         Puzzle  0.199118
# 6         Racing  0.326459
# 7   Role-Playing  0.196020
# 8        Shooter  0.395741
# 9     Simulation  0.206116
# 10        Sports  0.260615
# 11      Strategy  0.092928

# %%
df.groupby('Genre')['NA_Sales'].mean().plot(kind='bar', 
                                                title='NA', 
                                                fontsize=13, 
                                                color=['red', 'blue'], 
                                                alpha=0.4);

# %%
df.groupby('Genre')['JP_Sales'].mean().plot(kind='bar', 
                                                title='JP', 
                                                fontsize=13, 
                                                color=['red', 'blue'], 
                                                alpha=0.4);

# %%
df.groupby('Genre')['EU_Sales'].mean().plot(kind='bar', 
                                                title='EU', 
                                                fontsize=13, 
                                                color=['red', 'blue'], 
                                                alpha=0.4);

# %%
counts = df.groupby(['Year']).count()['Genre']
counts.plot(kind='bar', color=['red','blue'], title='Renaissance', fontsize=7, alpha=0.4);

# %%
group4 = df.groupby(['Genre'],as_index=False)['Year']
group4.head()
# Out:
# 0      2008
# 1      2009
# 2      2010
# 3      2010
# 4      2010
# 5      2005
# 6      2011
# 7      2005
# 8      2007
# 9      2011
# 10     2001
# 11     2003
# 12     2008
# 13     2005
# 14     2006
# 15     2009
# 16     2003
# 17     2014
# 18     2015
# 19     2009
# 20     2002
# 21     1997
# 22     2005
# 23     2014
# 24     2013
# 25     2002
# 26     1996
# 27     2011
# 28     2004
# 29     2000
# 30     2011
# 31     2007
# 32     2006
# 33     2015
# 34     2004
# 36     2005
# 37     1984
# 39     2006
# 40     2000
# 41     2004
# 42     2007
# 44     2013
# 49     2009
# 53     2009
# 54     2009
# 59     1985
# 61     2008
# 62     2010
# 64     2004
# 65     1998
# 68     2014
# 70     1999
# 78     2007
# 84     2000
# 93     2014
# 113    2005
# 121    1999
# 126    2011
# 128    2007
# 159    2007
# Name: Year, dtype: int64

# %%
df['Year_of_ten'] = df['Year'].map(lambda x: x//10*10)

Max = int(df.Year_of_ten.value_counts().index[0])
Min = int(df.Year_of_ten.value_counts().index[-1])

print('Max:',Max,'Min:',Min) #10년 단위로 변환, 가장많은 출시와 적은 출시 카운팅
# Out:
# Max: 2000 Min: 2020

# %%
df['Genre'].unique()
# Out:
# array(['Action', 'Adventure', 'Misc', 'Platform', 'Sports', 'Simulation',
#        'Racing', 'Role-Playing', 'Puzzle', 'Strategy', 'Fighting',
#        'Shooter'], dtype=object)

# %%
df['Year'].unique()
# Out:
# array([2008, 2009, 2010, 2005, 2011, 2007, 2001, 2003, 2006, 2014, 2015,
#        2002, 1997, 2013, 1996, 2004, 2000, 1984, 1998, 2016, 1985, 1999,
#        1995, 1993, 2012, 1987, 1982, 1994, 1990, 1992, 1991, 1983, 1988,
#        1981, 1989, 1986, 1980, 1978, 2017, 2020, 1979, 1977, 2018])

# %%
df.groupby(['Genre'],['Year']).sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-161-ef7d953c1ee5> in <module>()
# ----> 1 df.groupby(['Genre'],['Year']).sort_values(ascending=False)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7625         if level is None and by is None:
#    7626             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 7627         axis = self._get_axis_number(axis)
#    7628
#    7629         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     544     def _get_axis_number(cls, axis: Axis) -> int:
#     545         try:
# --> 546             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     547         except KeyError:
# ...

# %%
GenreYear = df.groupby(['Genre','Year'])
df.groupby(['Genre','Year']).size()
# Out:
# Genre         Year
# Action        1977      1
#               1978      1
#               1979      1
#               1980      3
#               1981     23
#               1982     18
#               1983      7
#               1984      1
#               1985      2
#               1986      5
#               1987      2
#               1988      2
#               1989      2
#               1990      3
#               1991      5
#               1992      1
#               1993      6
#               1994      4
#               1995      7
#               1996     18
#               1997     23
#               1998     40
#               1999     34
#               2000     38
#               2001     57
#               2002     91
#               2003     86
#               2004     76
#               2005    105
#               2006    125
#               2007    113
#               2008    118
#               2009    135
#               2010    120
# ...

# %%
GenreYear.T.plot(kind='bar')
plt.show()

# %%
GenreYear.plot.bar(rot=0)
plt.title("GenreYear")
plt.xlabel("Data")
plt.ylabel("Feature")
plt.ylim(1900, 2030)
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
df.sort_values('NA_Sales',ascending=False)

# %%
df.sort_values('JP_Sales',ascending=False)

# %%
df.sort_values('EU_Sales',ascending=False)

# %%
#All_Sales = df[['Name', 'EU_Sales','JP_Sales','NA_Sales','Other_Sales']]

df['All'] = df['EU_Sales'] + df['JP_Sales'] + df['NA_Sales'] + df['Other_Sales']
df
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import matplotlib
matplotlib.font_manager._rebuild()

All_Sales = df[['All', 'Name']]

All_Sales.set_index("Name",inplace=True)
plt.figure(figsize=(40,500))
All_Sales.plot()

# %%
All_Sales.sort_values('All',ascending=False)
# Out:
#                                                       All
# Name
# Wii Sports                                          82.74
# The Sims 2: Ikea Home Stuff                         70.02
# Super Mario Bros.                                   40.24
# Mario Kart Wii                                      35.83
# Wii Sports Resort                                   33.00
# Pokemon Red/Pokemon Blue                            31.38
# Tetris                                              30.26
# New Super Mario Bros.                               30.01
# Wii Play                                            29.01
# New Super Mario Bros. Wii                           28.61
# Duck Hunt                                           28.31
# Nintendogs                                          24.75
# Mario Kart DS                                       23.43
# Pokemon Gold/Pokemon Silver                         23.09
# Wii Fit                                             22.72
# ...

# %%
Report = All_Sales.sort_values('All',ascending=False).head(10)
Report
plt.rc('font',size=8)
plt.figure(figsize=(40,500))
Report.plot()
